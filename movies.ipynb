# %%
# Import the required libraries and dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm




from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, LabelEncoder
from sklearn.decomposition import PCA
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.svm import SVC 
from sklearn.neighbors import KNeighborsClassifier
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.metrics import balanced_accuracy_score, accuracy_score, classification_report, mean_squared_error, r2_score

# %%
# Read movies_metadata CSV file
tmdb_data = pd.read_csv('Resources/TMDB_all_movies.csv')
tmdb_data.head()
# Out:
#    id                             title  vote_average  vote_count    status  \
# 0   2                             Ariel           7.1       318.0  Released
# 1   3               Shadows in Paradise           7.3       360.0  Released
# 2   5                        Four Rooms           5.8      2578.0  Released
# 3   6                    Judgment Night           6.5       323.0  Released
# 4   8  Life in Loops (A Megacities RMX)           7.5        27.0  Released
#
#   release_date     revenue  runtime      budget    imdb_id  ...  \
# 0   1988-10-21         0.0     73.0         0.0  tt0094675  ...
# 1   1986-10-17         0.0     74.0         0.0  tt0092149  ...
# 2   1995-12-09   4257354.0     98.0   4000000.0  tt0113101  ...
# 3   1993-10-15  12136938.0    109.0  21000000.0  tt0107286  ...
# 4   2006-01-01         0.0     80.0     42000.0  tt0825671  ...
#
#                           genres  \
# 0  Drama, Comedy, Romance, Crime
# 1         Drama, Comedy, Romance
# 2                         Comedy
# 3        Action, Crime, Thriller
# 4                    Documentary
#
#                            production_companies      production_countries  \
# 0                     Villealfa Filmproductions                   Finland
# 1                     Villealfa Filmproductions                   Finland
# 2                         Miramax, A Band Apart  United States of America
# 3  Largo Entertainment, JVC, Universal Pictures  United States of America
# 4                                       inLoops                   Austria
#
#                          spoken_languages  \
# 0                                   suomi
# 1                 suomi, English, svenska
# 2                                 English
# 3                                 English
# 4  English, हिन्दी, 日本語, Pусский, Español
#
#                                                 cast  \
# 0  Kari Helaseppä, Susanna Haavisto, Hannu Kivisa...
# 1  Helmeri Pellonpää, Tanja Talaskivi, Esko Nikka...
# 2  Kimberly Blair, Sammi Davis, Paul Skemp, Bruce...
# 3  Doug Wert, Darin Mangan, Stephen Dorff, Nigel ...
# 4                                                NaN
#
#                                             director  \
# 0                                     Aki Kaurismäki
# 1                                     Aki Kaurismäki
# 2  Alexandre Rockwell, Quentin Tarantino, Allison...
# 3                                    Stephen Hopkins
# 4                                       Timo Novotny
#
#                              director_of_photography  \
# 0                                      Timo Salminen
# 1                                      Timo Salminen
# 2  Andrzej Sekula, Rodrigo García, Guillermo Nava...
# 3                                         Peter Levy
# 4                                    Wolfgang Thaler
#
#                                              writers  \
# 0                                     Aki Kaurismäki
# 1                                     Aki Kaurismäki
# 2  Alexandre Rockwell, Quentin Tarantino, Allison...
# 3                      Lewis Colick, Jere Cunningham
# 4                    Michael Glawogger, Timo Novotny
#
#                                            producers      music_composer
# 0                                     Aki Kaurismäki                 NaN
# 1                                    Mika Kaurismäki                 NaN
# 2  Alexandre Rockwell, Lawrence Bender, Quentin T...  Combustible Edison
# 3              Gene Levy, Marilyn Vance, Lloyd Segan      Alan Silvestri
# 4                     Ulrich Gehmacher, Timo Novotny                 NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Check for null values by finding the percentage in each column
tmdb_data.isnull().sum()/len(tmdb_data)*100
# Out:
# id                          0.000000
# title                       0.000632
# vote_average                0.000105
# vote_count                  0.000105
# status                      0.000105
# release_date                9.725145
# revenue                     0.000105
# runtime                     0.000105
# budget                      0.000105
# imdb_id                    40.222934
# original_language           0.000105
# original_title              0.000737
# overview                   16.779777
# popularity                  0.000105
# tagline                    85.191223
# genres                     28.776179
# production_companies       53.744426
# production_countries       38.760508
# spoken_languages           38.069947
# cast                       32.795166
# director                   17.367549
# director_of_photography    76.183916
# writers                    51.589754
# producers                  68.412184
# music_composer             90.188285
# dtype: float64

# %%
# Drop columns irrelevant to the analysis and can be dropped.
tmdb_data.drop(columns=['imdb_id','overview', 'tagline', 'director_of_photography', 'music_composer'],inplace=True)
tmdb_data.isnull().sum()/len(tmdb_data)*100
# Out:
# id                       0.000000
# title                    0.000632
# vote_average             0.000105
# vote_count               0.000105
# status                   0.000105
# release_date             9.725145
# revenue                  0.000105
# runtime                  0.000105
# budget                   0.000105
# original_language        0.000105
# original_title           0.000737
# popularity               0.000105
# genres                  28.776179
# production_companies    53.744426
# production_countries    38.760508
# spoken_languages        38.069947
# cast                    32.795166
# director                17.367549
# writers                 51.589754
# producers               68.412184
# dtype: float64

# %%
tmdb_data['status'].value_counts()
# Out:
# status
# Released           934732
# In Production        4591
# Planned              4546
# Post Production      4444
# Rumored               782
# Canceled              422
# Name: count, dtype: int64

# %%
tmdb_data['production_countries'].value_counts()
# Out:
# production_countries
# United States of America                137747
# Japan                                    36076
# United Kingdom                           32964
# France                                   31543
# Germany                                  30371
#                                          ...
# Czechoslovakia, Tunisia                      1
# France, Sweden, Tunisia                      1
# Ireland, Germany, Austria                    1
# Egypt, Lebanon, Syrian Arab Republic         1
# Costa Rica, Uruguay                          1
# Name: count, Length: 10350, dtype: int64

# %%
# Filter df to US production companies and movies that have been released
us_tmdb_df = tmdb_data.loc[(tmdb_data['production_countries'] == 'United States of America') & (tmdb_data['status']=='Released')]
us_tmdb_df.isnull().sum()/len(us_tmdb_df)*100
# Out:
# id                       0.000000
# title                    0.001485
# vote_average             0.000000
# vote_count               0.000000
# status                   0.000000
# release_date             1.390941
# revenue                  0.000000
# runtime                  0.000000
# budget                   0.000000
# original_language        0.000000
# original_title           0.002228
# popularity               0.000000
# genres                   8.073847
# production_companies    24.727270
# production_countries     0.000000
# spoken_languages        21.510207
# cast                    15.108758
# director                 9.362306
# writers                 34.216565
# producers               49.239178
# dtype: float64

# %%
us_tmdb_df.shape
# Out:
# (134657, 20)

# %%
us_tmdb_df['vote_average'].describe()
# Out:
# count    134657.000000
# mean          3.340277
# std           3.162888
# min           0.000000
# 25%           0.000000
# 50%           4.000000
# 75%           6.000000
# max          10.000000
# Name: vote_average, dtype: float64

# %%
'''
Question: How do we determine if a movie is a critical success?
Answer: Bin 'vote_average' column in the dataset needs based on the following guidelines:
0-2.5 = panned 
2.51-5 = alright
5.1-7.5 = well liked
7.51-10 = critical success
'''
# Out:
# "\nQuestion: How do we determine if a movie is a critical success?\nAnswer: Bin 'vote_average' column in the dataset needs based on the following guidelines:\n0-2.5 = panned \n2.51-5 = alright\n5.1-7.5 = well liked\n7.51-10 = critical success\n"

# %%
# Create bins in which to place values based upon 'vote_average' column
bins = [0, 2.5, 5, 7.5, 10]

critical_success = ['panned', 'alright', 'well liked', 'critical success']

# %%
# Slice the data and place it into bins
us_tmdb_df['critical_success'] = pd.cut(us_tmdb_df['vote_average'], bins, labels=critical_success, include_lowest=True)
us_tmdb_df.head()
# Out:
# /var/folders/nj/c0y0hsjn49j_mm6rq83vlmgc0000gn/T/ipykernel_30853/2712036490.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_tmdb_df['critical_success'] = pd.cut(us_tmdb_df['vote_average'], bins, labels=critical_success, include_lowest=True)
#    id           title  vote_average  vote_count    status release_date  \
# 2   5      Four Rooms         5.800      2578.0  Released   1995-12-09
# 3   6  Judgment Night         6.500       323.0  Released   1993-10-15
# 6  11       Star Wars         8.203     20152.0  Released   1977-05-25
# 7  12    Finding Nemo         7.821     18826.0  Released   2003-05-30
# 8  13    Forrest Gump         8.475     26790.0  Released   1994-06-23
#
#        revenue  runtime      budget original_language  ... popularity  \
# 2    4257354.0     98.0   4000000.0                en  ...     24.747
# 3   12136938.0    109.0  21000000.0                en  ...     27.882
# 6  775398007.0    121.0  11000000.0                en  ...    250.715
# 7  940335536.0    100.0  94000000.0                en  ...    124.166
# 8  677387716.0    142.0  55000000.0                en  ...    127.156
#
#                                genres  \
# 2                              Comedy
# 3             Action, Crime, Thriller
# 6  Adventure, Action, Science Fiction
# 7                   Animation, Family
# 8              Comedy, Drama, Romance
#
#                                 production_companies  \
# 2                              Miramax, A Band Apart
# 3       Largo Entertainment, JVC, Universal Pictures
# 6                   Lucasfilm Ltd., 20th Century Fox
# 7                                              Pixar
# 8  Paramount Pictures, The Steve Tisch Company, W...
#
#        production_countries spoken_languages  \
# 2  United States of America          English
# 3  United States of America          English
# 6  United States of America          English
# 7  United States of America          English
# 8  United States of America          English
#
#                                                 cast  \
# 2  Kimberly Blair, Sammi Davis, Paul Skemp, Bruce...
# 3  Doug Wert, Darin Mangan, Stephen Dorff, Nigel ...
# 6  Leslie Schofield, Don Henderson, David Prowse,...
# 7  Alexander Gould, Susan Blu, Michaela Jill Murp...
# 8  Angela Lomas, Geoffrey Blake, Zach Hanner, Mic...
#
#                                             director  \
# 2  Alexandre Rockwell, Quentin Tarantino, Allison...
# 3                                    Stephen Hopkins
# 6                                       George Lucas
# 7                                     Andrew Stanton
# 8                                    Robert Zemeckis
#
#                                              writers  \
# 2  Alexandre Rockwell, Quentin Tarantino, Allison...
# 3                      Lewis Colick, Jere Cunningham
# 6                                       George Lucas
# 7  Bob Peterson, Will Csaklos, Andrew Stanton, Ji...
# 8                           Winston Groom, Eric Roth
#
#                                            producers  critical_success
# 2  Alexandre Rockwell, Lawrence Bender, Quentin T...        well liked
# 3              Gene Levy, Marilyn Vance, Lloyd Segan        well liked
# 6            Rick McCallum, George Lucas, Gary Kurtz  critical success
# 7                      John Lasseter, Graham Walters  critical success
# 8         Steve Tisch, Steve Starkey, Wendy Finerman  critical success
#
# [5 rows x 21 columns]

# %%
us_tmdb_df.shape
# Out:
# (134657, 21)

# %%
'''
Question: How do we determine if a movie is a financial success?
Answer: Use ROI (Return on Investment) to determine if a movie is a financial success. 
ROI is calculated as follows: ROI = ((revenue-budget)/budget) * 100? 
Create 'roi' columun based on calculation and bin values based on the following guidelines:
<0% = failure
0% = broke even
0%<>50% = modest returns
50%<>100% = moderate returns
100%<>500% = excellent returns
>500% = extraordinary returns
'''
# Out:
# "\nQuestion: How do we determine if a movie is a financial success?\nAnswer: Use ROI (Return on Investment) to determine if a movie is a financial success. \nROI is calculated as follows: ROI = ((revenue-budget)/budget) * 100? \nCreate 'roi' columun based on calculation and bin values based on the following guidelines:\n<0% = failure\n0% = broke even\n0%<>50% = modest returns\n50%<>100% = moderate returns\n100%<>500% = excellent returns\n>500% = extraordinary returns\n"

# %%
# Determine the dimensions of the dataframe when the budget is 0
# us_tmdb_df[us_tmdb_df['budget'] == 0]
us_tmdb_df.loc[us_tmdb_df['budget'] == 0]
# Out:
#              id                                            title  \
# 16           21                               The Endless Summer
# 94          132                                    Gimme Shelter
# 95          133                                          Primary
# 97          135                                  Don't Look Back
# 154         195                              Trouble in Paradise
# ...         ...                                              ...
# 949411  1308786                        The Seagull on the Sims 4
# 949428  1308804                                         Two Cops
# 949462  1308839                                    Computer love
# 949463  1308840  Power Slap 8: Da Crazy Hawaiian vs. Van Heerden
# 949479  1308860                                          Game On
#
#         vote_average  vote_count    status release_date   revenue  runtime  \
# 16               7.2       109.0  Released   1966-06-15       0.0     91.0
# 94               7.4       159.0  Released   1970-12-13  252570.0     92.0
# 95               6.5        30.0  Released   1960-11-08       0.0     53.0
# 97               7.5       141.0  Released   1967-05-17       0.0     96.0
# 154              7.4       267.0  Released   1932-10-30       0.0     83.0
# ...              ...         ...       ...          ...       ...      ...
# 949411           0.0         0.0  Released   2020-10-27       0.0    318.0
# 949428           0.0         0.0  Released   2019-09-13       0.0     30.0
# 949462           0.0         0.0  Released   2022-06-02       0.0      0.0
# 949463           0.0         0.0  Released   2024-06-28       0.0    180.0
# 949479           0.0         0.0  Released   2024-06-18       0.0    114.0
#
#         budget original_language  ... popularity  \
# 16         0.0                en  ...      7.374
# 94         0.0                en  ...     20.296
# 95         0.0                en  ...      3.257
# 97         0.0                en  ...     13.256
# 154        0.0                en  ...      9.003
# ...        ...               ...  ...        ...
# 949411     0.0                en  ...      0.000
# 949428     0.0                en  ...      0.000
# 949462     0.0                en  ...      0.000
# 949463     0.0                en  ...      0.000
# 949479     0.0                en  ...      0.000
#
#                                   genres       production_companies  \
# 16                           Documentary          Bruce Brown Films
# 94                    Documentary, Music              Maysles Films
# 95                           Documentary            Drew Associates
# 97                    Documentary, Music         Leacock-Pennebaker
# 154               Comedy, Crime, Romance                  Paramount
# ...                                  ...                        ...
# 949411                  Drama, Animation  New York Theatre Workshop
# 949428                               NaN                        NaN
# 949462  Comedy, Romance, Science Fiction                        NaN
# 949463                            Action                        NaN
# 949479                               NaN               Sweet Sinner
#
#             production_countries  \
# 16      United States of America
# 94      United States of America
# 95      United States of America
# 97      United States of America
# 154     United States of America
# ...                          ...
# 949411  United States of America
# 949428  United States of America
# 949462  United States of America
# 949463  United States of America
# 949479  United States of America
#
#                                     spoken_languages  \
# 16                                           English
# 94                                           English
# 95                                           English
# 97                                           English
# 154     Deutsch, English, Español, Italiano, Pусский
# ...                                              ...
# 949411                                           NaN
# 949428                                       English
# 949462                                       English
# 949463                                       English
# 949479                                           NaN
#
#                                                      cast  \
# 16      Chuck Gardner, Wayne Miyata, Robert August, Lo...
# 94      Jorma Kaukonen, Rock Scully, Marty Balin, Keit...
# 95      John F. Kennedy, Robert Drew, Pierre Salinger,...
# 97      Tito Burns, Albert Grossman, Derroll Adams, Al...
# 154     George Humbert, Tyler Brooke, Marion Byron, St...
# ...                                                   ...
# 949411  Jiehae Park, Celine Song, Jim Nicola, C.A. Joh...
# 949428                            Eric Cohen, Steve Cohen
# 949462  Ryan Scott Morris, Anne Stedman, Ali Gallo, Sh...
# 949463  Dan Hellie, Charly Arnolt, Justin Bernard, Mic...
# 949479  Freya Parker, Will Pounder, Alex Coal, Ryan Dr...
#
#                                                director  \
# 16                                          Bruce Brown
# 94      Albert Maysles, Charlotte Zwerin, David Maysles
# 95                                          Robert Drew
# 97                                     D. A. Pennebaker
# 154                                      Ernst Lubitsch
# ...                                                 ...
# 949411                                      Celine Song
# 949428                                      Tova Mozard
# 949462                                   Joseph Picozzi
# 949463                                              NaN
# 949479                                              NaN
#
#                                                   writers  \
# 16                                            Bruce Brown
# 94                                                    NaN
# 95                                            Robert Drew
# 97                                       D. A. Pennebaker
# 154     Samson Raphaelson, Aladar Laszlo, Grover Jones...
# ...                                                   ...
# 949411                         Anton Chekhov, Celine Song
# 949428                                                NaN
# 949462                                     Joseph Picozzi
# 949463                                                NaN
# 949479                                                NaN
#
#                           producers critical_success
# 16       Robert Bagley, Bruce Brown       well liked
# 94                 Ronald Schneider       well liked
# 95                      Robert Drew       well liked
# 97      John Court, Albert Grossman       well liked
# 154                  Ernst Lubitsch       well liked
# ...                             ...              ...
# 949411                          NaN           panned
# 949428                          NaN           panned
# 949462               Joseph Picozzi           panned
# 949463                          NaN           panned
# 949479                          NaN           panned
#
# [118929 rows x 21 columns]

# %%
# Filter through budget columns to select rows with budget not equal to 0
# us_tmdb_df = us_tmdb_df.loc[us_tmdb_df['budget'] != 0].copy()

us_tmdb_df = us_tmdb_df[us_tmdb_df['budget'] != 0].copy()

# Check bugdet column for 0 values
us_tmdb_df['budget'].loc[us_tmdb_df['budget'] == 0]

us_tmdb_df.shape
# Out:
# (15728, 21)

# %%
# Calculate ROI and as metric for financial success based on revenue and budget
us_tmdb_df['roi'] = ((us_tmdb_df['revenue'] - us_tmdb_df['budget'])/us_tmdb_df['budget'])*100

us_tmdb_df.head()
# Out:
#    id           title  vote_average  vote_count    status release_date  \
# 2   5      Four Rooms         5.800      2578.0  Released   1995-12-09
# 3   6  Judgment Night         6.500       323.0  Released   1993-10-15
# 6  11       Star Wars         8.203     20152.0  Released   1977-05-25
# 7  12    Finding Nemo         7.821     18826.0  Released   2003-05-30
# 8  13    Forrest Gump         8.475     26790.0  Released   1994-06-23
#
#        revenue  runtime      budget original_language  ...  \
# 2    4257354.0     98.0   4000000.0                en  ...
# 3   12136938.0    109.0  21000000.0                en  ...
# 6  775398007.0    121.0  11000000.0                en  ...
# 7  940335536.0    100.0  94000000.0                en  ...
# 8  677387716.0    142.0  55000000.0                en  ...
#
#                                genres  \
# 2                              Comedy
# 3             Action, Crime, Thriller
# 6  Adventure, Action, Science Fiction
# 7                   Animation, Family
# 8              Comedy, Drama, Romance
#
#                                 production_companies  \
# 2                              Miramax, A Band Apart
# 3       Largo Entertainment, JVC, Universal Pictures
# 6                   Lucasfilm Ltd., 20th Century Fox
# 7                                              Pixar
# 8  Paramount Pictures, The Steve Tisch Company, W...
#
#        production_countries spoken_languages  \
# 2  United States of America          English
# 3  United States of America          English
# 6  United States of America          English
# 7  United States of America          English
# 8  United States of America          English
#
#                                                 cast  \
# 2  Kimberly Blair, Sammi Davis, Paul Skemp, Bruce...
# 3  Doug Wert, Darin Mangan, Stephen Dorff, Nigel ...
# 6  Leslie Schofield, Don Henderson, David Prowse,...
# 7  Alexander Gould, Susan Blu, Michaela Jill Murp...
# 8  Angela Lomas, Geoffrey Blake, Zach Hanner, Mic...
#
#                                             director  \
# 2  Alexandre Rockwell, Quentin Tarantino, Allison...
# 3                                    Stephen Hopkins
# 6                                       George Lucas
# 7                                     Andrew Stanton
# 8                                    Robert Zemeckis
#
#                                              writers  \
# 2  Alexandre Rockwell, Quentin Tarantino, Allison...
# 3                      Lewis Colick, Jere Cunningham
# 6                                       George Lucas
# 7  Bob Peterson, Will Csaklos, Andrew Stanton, Ji...
# 8                           Winston Groom, Eric Roth
#
#                                            producers  critical_success  \
# 2  Alexandre Rockwell, Lawrence Bender, Quentin T...        well liked
# 3              Gene Levy, Marilyn Vance, Lloyd Segan        well liked
# 6            Rick McCallum, George Lucas, Gary Kurtz  critical success
# 7                      John Lasseter, Graham Walters  critical success
# 8         Steve Tisch, Steve Starkey, Wendy Finerman  critical success
#
#            roi
# 2     6.433850
# 3   -42.205057
# 6  6949.072791
# 7   900.356953
# 8  1131.614029
#
# [5 rows x 22 columns]

# %%
us_tmdb_df['roi'].describe()
# Out:
# count    1.572800e+04
# mean     2.092805e+05
# std      1.786877e+07
# min     -2.000000e+02
# 25%     -1.000000e+02
# 50%     -1.000000e+02
# 75%      0.000000e+00
# max      2.000000e+09
# Name: roi, dtype: float64

# %%
us_tmdb_df.loc[us_tmdb_df['roi'] == 0]
# Out:
#              id                     title  vote_average  vote_count    status  \
# 3677       6883        Two-Minute Warning         6.100        84.0  Released
# 4605       9409          Another Stakeout         5.500       209.0  Released
# 12021     19933  The Brave Little Toaster         6.900       415.0  Released
# 13651     22887   Loose Change: Final Cut         6.313        40.0  Released
# 21113     33689              It Takes Two         6.500       858.0  Released
# ...         ...                       ...           ...         ...       ...
# 908665  1262469             Opportunities        10.000         1.0  Released
# 911082  1265226   The Bill Land Dance Off         0.000         0.0  Released
# 921973  1277446    The Wake of Flip Fitch         0.000         0.0  Released
# 940159  1298360               Hit And Run         0.000         0.0  Released
# 942528  1301095      Swagmaster Interview         0.000         0.0  Released
#
#        release_date     revenue  runtime      budget original_language  ...  \
# 3677     1976-11-12   6700000.0    115.0   6700000.0                en  ...
# 4605     1993-07-22  30000000.0    105.0  30000000.0                en  ...
# 12021    1987-07-09   2300000.0     90.0   2300000.0                en  ...
# 13651    2007-11-11      6000.0    129.0      6000.0                en  ...
# 21113    1995-11-17  19474589.0    101.0  19474589.0                en  ...
# ...             ...         ...      ...         ...               ...  ...
# 908665   2023-05-20       444.0     12.0       444.0                en  ...
# 911082   2024-06-01         1.0     10.0         1.0                en  ...
# 921973   2023-12-08       200.0     50.0       200.0                en  ...
# 940159   2024-05-31         1.0      1.0         1.0                en  ...
# 942528   2024-06-29        40.0      3.0        40.0                en  ...
#
#                                        genres  \
# 3677                         Action, Thriller
# 4605                    Comedy, Crime, Action
# 12021   Animation, Adventure, Family, Fantasy
# 13651                             Documentary
# 21113                 Comedy, Family, Romance
# ...                                       ...
# 908665  Adventure, Drama, Thriller, Animation
# 911082                                  Drama
# 921973                          Music, Horror
# 940159                          Drama, Action
# 942528     Documentary, Horror, Thriller, War
#
#                                      production_companies  \
# 3677                Universal Pictures, Filmways Pictures
# 4605                                  Touchstone Pictures
# 12021   The Kushner-Locke Company, Hyperion Pictures, ...
# 13651                                   Louder Than Words
# 21113   Dualstar Productions, Orr & Cruickshank, Ryshe...
# ...                                                   ...
# 908665                             Pink Moose Productions
# 911082                                             BAEBUH
# 921973                                 Ogus Entertainment
# 940159                                   BlazeProductions
# 942528  buggington productions, hungerford producting ...
#
#             production_countries          spoken_languages  \
# 3677    United States of America                   English
# 4605    United States of America                   English
# 12021   United States of America  Polski, Español, English
# 13651   United States of America                   English
# 21113   United States of America                   English
# ...                          ...                       ...
# 908665  United States of America                   English
# 911082  United States of America                   English
# 921973  United States of America                       NaN
# 940159  United States of America                   English
# 942528  United States of America                   English
#
#                                                      cast  \
# 3677    John Stuart West, William Bryant, Andy Sidaris...
# 4605    Cathy Moriarty, Denalda Williams, Jan Speck, R...
# 12021   Joe Ranft, Jon Lovitz, Jonathan Benair, Wayne ...
# 13651                                      Richard Shelby
# 21113   Michèle Lonsdale Smith, Elizabeth Walsh, Kirst...
# ...                                                   ...
# 908665  Kevin Glass, Josh Buraczewski, Ross Moshinsky,...
# 911082                        Jate, Tim, Mita, Rizzy, Nit
# 921973  Feck Speiderbeck, Flip Fitch, Mateo Molina, DJ...
# 940159                     Brodie, Wall, Hat, Adam Toland
# 942528  Justin Goldman, Diego Vazquez, Anton Pozhitkov...
#
#                             director  \
# 3677                    Larry Peerce
# 4605                     John Badham
# 12021                     Jerry Rees
# 13651                    Dylan Avery
# 21113                   Andy Tennant
# ...                              ...
# 908665          Matthew Francis Hess
# 911082                           Nit
# 921973  Feck Speiderbeck, Flip Fitch
# 940159                   Adam Toland
# 942528                Matthias Zafra
#
#                                                   writers  \
# 3677                 George La Fountaine Sr., Edward Hume
# 4605                                  Jim Kouf, Lynn Kouf
# 12021   Jerry Rees, Joe Ranft, Thomas M. Disch, Brian ...
# 13651                                         Dylan Avery
# 21113                                  Deborah Dean Davis
# ...                                                   ...
# 908665      Wes Peppers, Corey Dowd, Matthew Francis Hess
# 911082                                              Rizzy
# 921973                                                NaN
# 940159                                        Adam Toland
# 942528                                                NaN
#
#                                                 producers  critical_success  \
# 3677                                    Edward S. Feldman        well liked
# 4605    Cathleen Summers, John Badham, Jim Kouf, Lynn ...        well liked
# 12021   Willard Carroll, Thomas L. Wilhite, Peter Lock...        well liked
# 13651                                                 NaN        well liked
# 21113   Mel Efros, James Orr, Jim Cruickshank, Keith S...        well liked
# ...                                                   ...               ...
# 908665  Josh Triezenberg, Matthew Francis Hess, Laura ...  critical success
# 911082                                                Tim            panned
# 921973                                                NaN            panned
# 940159                                        Adam Toland            panned
# 942528  Justin Goldman, Matthias Zafra, Anton Pozhitko...            panned
#
#         roi
# 3677    0.0
# 4605    0.0
# 12021   0.0
# 13651   0.0
# 21113   0.0
# ...     ...
# 908665  0.0
# 911082  0.0
# 921973  0.0
# 940159  0.0
# 942528  0.0
#
# [132 rows x 22 columns]

# %%
# Create bins in which to place values based upon roi column
bins = [-float('inf'), 0, 50, 100, 500, float('inf')]

financial_success = ['failure', 'modest returns', 
                    'moderate returns', 'excellent returns', 'extraordinary returns']

# %%
# Slice the data and place it into bins
us_tmdb_df['financial_success'] = pd.cut(us_tmdb_df['roi'], bins, labels=financial_success, include_lowest=True)

# Add the new category 'broke even' to the financial_success column
us_tmdb_df['financial_success'] = us_tmdb_df['financial_success'].cat.add_categories('broke even')

# Handle the special case where roi equals 0
us_tmdb_df.loc[us_tmdb_df['roi'] == 0, 'financial_success'] = 'broke even'

# %%
# Check to ensure when roi is 0, financial_success is 'broke even'
us_tmdb_df.loc[us_tmdb_df['roi'] == 0]
# Out:
#              id                     title  vote_average  vote_count    status  \
# 3677       6883        Two-Minute Warning         6.100        84.0  Released
# 4605       9409          Another Stakeout         5.500       209.0  Released
# 12021     19933  The Brave Little Toaster         6.900       415.0  Released
# 13651     22887   Loose Change: Final Cut         6.313        40.0  Released
# 21113     33689              It Takes Two         6.500       858.0  Released
# ...         ...                       ...           ...         ...       ...
# 908665  1262469             Opportunities        10.000         1.0  Released
# 911082  1265226   The Bill Land Dance Off         0.000         0.0  Released
# 921973  1277446    The Wake of Flip Fitch         0.000         0.0  Released
# 940159  1298360               Hit And Run         0.000         0.0  Released
# 942528  1301095      Swagmaster Interview         0.000         0.0  Released
#
#        release_date     revenue  runtime      budget original_language  ...  \
# 3677     1976-11-12   6700000.0    115.0   6700000.0                en  ...
# 4605     1993-07-22  30000000.0    105.0  30000000.0                en  ...
# 12021    1987-07-09   2300000.0     90.0   2300000.0                en  ...
# 13651    2007-11-11      6000.0    129.0      6000.0                en  ...
# 21113    1995-11-17  19474589.0    101.0  19474589.0                en  ...
# ...             ...         ...      ...         ...               ...  ...
# 908665   2023-05-20       444.0     12.0       444.0                en  ...
# 911082   2024-06-01         1.0     10.0         1.0                en  ...
# 921973   2023-12-08       200.0     50.0       200.0                en  ...
# 940159   2024-05-31         1.0      1.0         1.0                en  ...
# 942528   2024-06-29        40.0      3.0        40.0                en  ...
#
#                                      production_companies  \
# 3677                Universal Pictures, Filmways Pictures
# 4605                                  Touchstone Pictures
# 12021   The Kushner-Locke Company, Hyperion Pictures, ...
# 13651                                   Louder Than Words
# 21113   Dualstar Productions, Orr & Cruickshank, Ryshe...
# ...                                                   ...
# 908665                             Pink Moose Productions
# 911082                                             BAEBUH
# 921973                                 Ogus Entertainment
# 940159                                   BlazeProductions
# 942528  buggington productions, hungerford producting ...
#
#             production_countries          spoken_languages  \
# 3677    United States of America                   English
# 4605    United States of America                   English
# 12021   United States of America  Polski, Español, English
# 13651   United States of America                   English
# 21113   United States of America                   English
# ...                          ...                       ...
# 908665  United States of America                   English
# 911082  United States of America                   English
# 921973  United States of America                       NaN
# 940159  United States of America                   English
# 942528  United States of America                   English
#
#                                                      cast  \
# 3677    John Stuart West, William Bryant, Andy Sidaris...
# 4605    Cathy Moriarty, Denalda Williams, Jan Speck, R...
# 12021   Joe Ranft, Jon Lovitz, Jonathan Benair, Wayne ...
# 13651                                      Richard Shelby
# 21113   Michèle Lonsdale Smith, Elizabeth Walsh, Kirst...
# ...                                                   ...
# 908665  Kevin Glass, Josh Buraczewski, Ross Moshinsky,...
# 911082                        Jate, Tim, Mita, Rizzy, Nit
# 921973  Feck Speiderbeck, Flip Fitch, Mateo Molina, DJ...
# 940159                     Brodie, Wall, Hat, Adam Toland
# 942528  Justin Goldman, Diego Vazquez, Anton Pozhitkov...
#
#                             director  \
# 3677                    Larry Peerce
# 4605                     John Badham
# 12021                     Jerry Rees
# 13651                    Dylan Avery
# 21113                   Andy Tennant
# ...                              ...
# 908665          Matthew Francis Hess
# 911082                           Nit
# 921973  Feck Speiderbeck, Flip Fitch
# 940159                   Adam Toland
# 942528                Matthias Zafra
#
#                                                   writers  \
# 3677                 George La Fountaine Sr., Edward Hume
# 4605                                  Jim Kouf, Lynn Kouf
# 12021   Jerry Rees, Joe Ranft, Thomas M. Disch, Brian ...
# 13651                                         Dylan Avery
# 21113                                  Deborah Dean Davis
# ...                                                   ...
# 908665      Wes Peppers, Corey Dowd, Matthew Francis Hess
# 911082                                              Rizzy
# 921973                                                NaN
# 940159                                        Adam Toland
# 942528                                                NaN
#
#                                                 producers  critical_success  \
# 3677                                    Edward S. Feldman        well liked
# 4605    Cathleen Summers, John Badham, Jim Kouf, Lynn ...        well liked
# 12021   Willard Carroll, Thomas L. Wilhite, Peter Lock...        well liked
# 13651                                                 NaN        well liked
# 21113   Mel Efros, James Orr, Jim Cruickshank, Keith S...        well liked
# ...                                                   ...               ...
# 908665  Josh Triezenberg, Matthew Francis Hess, Laura ...  critical success
# 911082                                                Tim            panned
# 921973                                                NaN            panned
# 940159                                        Adam Toland            panned
# 942528  Justin Goldman, Matthias Zafra, Anton Pozhitko...            panned
#
#         roi financial_success
# 3677    0.0        broke even
# 4605    0.0        broke even
# 12021   0.0        broke even
# 13651   0.0        broke even
# 21113   0.0        broke even
# ...     ...               ...
# 908665  0.0        broke even
# 911082  0.0        broke even
# 921973  0.0        broke even
# 940159  0.0        broke even
# 942528  0.0        broke even
#
# [132 rows x 23 columns]

# %%
# Convert 'release_date' column to datetime
us_tmdb_df['release_date'] = pd.to_datetime(us_tmdb_df['release_date'], format='%Y-%m-%d', errors='coerce')


us_tmdb_df.dtypes
# Out:
# id                               int64
# title                           object
# vote_average                   float64
# vote_count                     float64
# status                          object
# release_date            datetime64[ns]
# revenue                        float64
# runtime                        float64
# budget                         float64
# original_language               object
# original_title                  object
# popularity                     float64
# genres                          object
# production_companies            object
# production_countries            object
# spoken_languages                object
# cast                            object
# director                        object
# writers                         object
# producers                       object
# critical_success              category
# roi                            float64
# financial_success             category
# dtype: object

# %%
us_tmdb_df.shape
# Out:
# (15728, 23)

# %%
# Check the release_date column for NaT (Not a Time) values 
us_tmdb_df['release_date'].isna().sum()

# us_tmdb_df[us_tmdb_df['release_date'].isna()]

# us_tmdb_df['release_date'].isna().sum()/len(us_tmdb_df)*100
# Out:
# 365

# %%
# Drop rows where 'release_date' is NaT
us_tmdb_df.dropna(subset=['release_date'], inplace=True)

# %%
# Check the release_date column for NaT (Not a Time) values 
us_tmdb_df['release_date'].isna().sum()
# us_tmdb_df.shape
# Out:
# 0

# %%
# Extract year, month, and day from 'release_date' column
us_tmdb_df['released_year'] = us_tmdb_df['release_date'].dt.year
us_tmdb_df['released_month'] = us_tmdb_df['release_date'].dt.month
us_tmdb_df['released_day'] = us_tmdb_df['release_date'].dt.day
us_tmdb_df.head()
# Out:
#    id           title  vote_average  vote_count    status release_date  \
# 2   5      Four Rooms         5.800      2578.0  Released   1995-12-09
# 3   6  Judgment Night         6.500       323.0  Released   1993-10-15
# 6  11       Star Wars         8.203     20152.0  Released   1977-05-25
# 7  12    Finding Nemo         7.821     18826.0  Released   2003-05-30
# 8  13    Forrest Gump         8.475     26790.0  Released   1994-06-23
#
#        revenue  runtime      budget original_language  ...  \
# 2    4257354.0     98.0   4000000.0                en  ...
# 3   12136938.0    109.0  21000000.0                en  ...
# 6  775398007.0    121.0  11000000.0                en  ...
# 7  940335536.0    100.0  94000000.0                en  ...
# 8  677387716.0    142.0  55000000.0                en  ...
#
#                                                 cast  \
# 2  Kimberly Blair, Sammi Davis, Paul Skemp, Bruce...
# 3  Doug Wert, Darin Mangan, Stephen Dorff, Nigel ...
# 6  Leslie Schofield, Don Henderson, David Prowse,...
# 7  Alexander Gould, Susan Blu, Michaela Jill Murp...
# 8  Angela Lomas, Geoffrey Blake, Zach Hanner, Mic...
#
#                                             director  \
# 2  Alexandre Rockwell, Quentin Tarantino, Allison...
# 3                                    Stephen Hopkins
# 6                                       George Lucas
# 7                                     Andrew Stanton
# 8                                    Robert Zemeckis
#
#                                              writers  \
# 2  Alexandre Rockwell, Quentin Tarantino, Allison...
# 3                      Lewis Colick, Jere Cunningham
# 6                                       George Lucas
# 7  Bob Peterson, Will Csaklos, Andrew Stanton, Ji...
# 8                           Winston Groom, Eric Roth
#
#                                            producers  critical_success  \
# 2  Alexandre Rockwell, Lawrence Bender, Quentin T...        well liked
# 3              Gene Levy, Marilyn Vance, Lloyd Segan        well liked
# 6            Rick McCallum, George Lucas, Gary Kurtz  critical success
# 7                      John Lasseter, Graham Walters  critical success
# 8         Steve Tisch, Steve Starkey, Wendy Finerman  critical success
#
#            roi      financial_success released_year released_month  \
# 2     6.433850         modest returns          1995             12
# 3   -42.205057                failure          1993             10
# 6  6949.072791  extraordinary returns          1977              5
# 7   900.356953  extraordinary returns          2003              5
# 8  1131.614029  extraordinary returns          1994              6
#
#   released_day
# 2            9
# 3           15
# 6           25
# 7           30
# 8           23
#
# [5 rows x 26 columns]

# %%
# Convert the released_year, released_month, and released_day columns to integers. 
us_tmdb_df['released_year'] = us_tmdb_df['released_year'].astype(int)
us_tmdb_df['released_month'] = us_tmdb_df['released_month'].astype(int)
us_tmdb_df['released_day'] = us_tmdb_df['released_day'].astype(int)
us_tmdb_df.head()
# Out:
#    id           title  vote_average  vote_count    status release_date  \
# 2   5      Four Rooms         5.800      2578.0  Released   1995-12-09
# 3   6  Judgment Night         6.500       323.0  Released   1993-10-15
# 6  11       Star Wars         8.203     20152.0  Released   1977-05-25
# 7  12    Finding Nemo         7.821     18826.0  Released   2003-05-30
# 8  13    Forrest Gump         8.475     26790.0  Released   1994-06-23
#
#        revenue  runtime      budget original_language  ...  \
# 2    4257354.0     98.0   4000000.0                en  ...
# 3   12136938.0    109.0  21000000.0                en  ...
# 6  775398007.0    121.0  11000000.0                en  ...
# 7  940335536.0    100.0  94000000.0                en  ...
# 8  677387716.0    142.0  55000000.0                en  ...
#
#                                                 cast  \
# 2  Kimberly Blair, Sammi Davis, Paul Skemp, Bruce...
# 3  Doug Wert, Darin Mangan, Stephen Dorff, Nigel ...
# 6  Leslie Schofield, Don Henderson, David Prowse,...
# 7  Alexander Gould, Susan Blu, Michaela Jill Murp...
# 8  Angela Lomas, Geoffrey Blake, Zach Hanner, Mic...
#
#                                             director  \
# 2  Alexandre Rockwell, Quentin Tarantino, Allison...
# 3                                    Stephen Hopkins
# 6                                       George Lucas
# 7                                     Andrew Stanton
# 8                                    Robert Zemeckis
#
#                                              writers  \
# 2  Alexandre Rockwell, Quentin Tarantino, Allison...
# 3                      Lewis Colick, Jere Cunningham
# 6                                       George Lucas
# 7  Bob Peterson, Will Csaklos, Andrew Stanton, Ji...
# 8                           Winston Groom, Eric Roth
#
#                                            producers  critical_success  \
# 2  Alexandre Rockwell, Lawrence Bender, Quentin T...        well liked
# 3              Gene Levy, Marilyn Vance, Lloyd Segan        well liked
# 6            Rick McCallum, George Lucas, Gary Kurtz  critical success
# 7                      John Lasseter, Graham Walters  critical success
# 8         Steve Tisch, Steve Starkey, Wendy Finerman  critical success
#
#            roi      financial_success released_year released_month  \
# 2     6.433850         modest returns          1995             12
# 3   -42.205057                failure          1993             10
# 6  6949.072791  extraordinary returns          1977              5
# 7   900.356953  extraordinary returns          2003              5
# 8  1131.614029  extraordinary returns          1994              6
#
#   released_day
# 2            9
# 3           15
# 6           25
# 7           30
# 8           23
#
# [5 rows x 26 columns]

# %%
us_tmdb_df['genres'].value_counts()
# Out:
# genres
# Drama                               1343
# Comedy                               994
# Horror                               986
# Documentary                          796
# Comedy, Drama                        377
#                                     ...
# Documentary, Music, TV Movie           1
# Thriller, Drama, Crime, TV Movie       1
# Action, Drama, Horror, War             1
# TV Movie, Comedy, Drama, Romance       1
# Horror, Romance, Thriller, Music       1
# Name: count, Length: 2208, dtype: int64

# %%
# Split the genre strings into lists of individual genres
us_tmdb_df = us_tmdb_df.copy()
us_tmdb_df['genres'] = us_tmdb_df['genres'].str.split(',')

# Seperate rows with a lists of genres into individual rows
us_tmdb_df = us_tmdb_df.explode('genres')

# Strip white spaces from the genre column
us_tmdb_df['genres'] = us_tmdb_df['genres'].str.strip()

# Recount the occurrences of each genre
us_tmdb_df['genres'].value_counts()
# Out:
# genres
# Drama              5620
# Comedy             4736
# Horror             3340
# Thriller           2868
# Action             2263
# Romance            1868
# Crime              1549
# Science Fiction    1513
# Adventure          1314
# Documentary        1191
# Family              954
# Mystery             953
# Fantasy             944
# Animation           647
# Music               607
# History             336
# War                 297
# Western             291
# TV Movie            208
# Name: count, dtype: int64

# %%
# Identify duplicate rows in a DataFrame across all or specific columns.
# us_tmdb_duplicate = us_tmdb_df[us_tmdb_df.duplicated(subset=['title'], keep=False)]
us_tmdb_duplicate = us_tmdb_df[us_tmdb_df.duplicated(subset=['id'], keep=False)]
us_tmdb_duplicate
# Out:
#              id                        title  vote_average  vote_count  \
# 3             6               Judgment Night         6.500       323.0
# 3             6               Judgment Night         6.500       323.0
# 3             6               Judgment Night         6.500       323.0
# 6            11                    Star Wars         8.203     20152.0
# 6            11                    Star Wars         8.203     20152.0
# ...         ...                          ...           ...         ...
# 948247  1307509                      Doc Ock         0.000         0.0
# 948247  1307509                      Doc Ock         0.000         0.0
# 948247  1307509                      Doc Ock         0.000         0.0
# 948302  1307570  12 oz. Mouse (DVD MOVIECUT)         0.000         0.0
# 948302  1307570  12 oz. Mouse (DVD MOVIECUT)         0.000         0.0
#
#           status release_date      revenue  runtime      budget  \
# 3       Released   1993-10-15   12136938.0    109.0  21000000.0
# 3       Released   1993-10-15   12136938.0    109.0  21000000.0
# 3       Released   1993-10-15   12136938.0    109.0  21000000.0
# 6       Released   1977-05-25  775398007.0    121.0  11000000.0
# 6       Released   1977-05-25  775398007.0    121.0  11000000.0
# ...          ...          ...          ...      ...         ...
# 948247  Released   2024-06-27          0.0     14.0       100.0
# 948247  Released   2024-06-27          0.0     14.0       100.0
# 948247  Released   2024-06-27          0.0     14.0       100.0
# 948302  Released   2008-02-29          0.0    208.0       100.0
# 948302  Released   2008-02-29          0.0    208.0       100.0
#
#        original_language  ...  \
# 3                     en  ...
# 3                     en  ...
# 3                     en  ...
# 6                     en  ...
# 6                     en  ...
# ...                  ...  ...
# 948247                en  ...
# 948247                en  ...
# 948247                en  ...
# 948302                en  ...
# 948302                en  ...
#
#                                                      cast         director  \
# 3       Doug Wert, Darin Mangan, Stephen Dorff, Nigel ...  Stephen Hopkins
# 3       Doug Wert, Darin Mangan, Stephen Dorff, Nigel ...  Stephen Hopkins
# 3       Doug Wert, Darin Mangan, Stephen Dorff, Nigel ...  Stephen Hopkins
# 6       Leslie Schofield, Don Henderson, David Prowse,...     George Lucas
# 6       Leslie Schofield, Don Henderson, David Prowse,...     George Lucas
# ...                                                   ...              ...
# 948247                                                NaN      Peter Dudka
# 948247                                                NaN      Peter Dudka
# 948247                                                NaN      Peter Dudka
# 948302  Matt Maiellaro, Kurt Soccolich, Matt Harrigan,...   Matt Maiellaro
# 948302  Matt Maiellaro, Kurt Soccolich, Matt Harrigan,...   Matt Maiellaro
#
#                               writers  \
# 3       Lewis Colick, Jere Cunningham
# 3       Lewis Colick, Jere Cunningham
# 3       Lewis Colick, Jere Cunningham
# 6                        George Lucas
# 6                        George Lucas
# ...                               ...
# 948247                            NaN
# 948247                            NaN
# 948247                            NaN
# 948302                            NaN
# 948302                            NaN
#
#                                       producers  critical_success  \
# 3         Gene Levy, Marilyn Vance, Lloyd Segan        well liked
# 3         Gene Levy, Marilyn Vance, Lloyd Segan        well liked
# 3         Gene Levy, Marilyn Vance, Lloyd Segan        well liked
# 6       Rick McCallum, George Lucas, Gary Kurtz  critical success
# 6       Rick McCallum, George Lucas, Gary Kurtz  critical success
# ...                                         ...               ...
# 948247                                      NaN            panned
# 948247                                      NaN            panned
# 948247                                      NaN            panned
# 948302                                      NaN            panned
# 948302                                      NaN            panned
#
#                 roi      financial_success released_year released_month  \
# 3        -42.205057                failure          1993             10
# 3        -42.205057                failure          1993             10
# 3        -42.205057                failure          1993             10
# 6       6949.072791  extraordinary returns          1977              5
# 6       6949.072791  extraordinary returns          1977              5
# ...             ...                    ...           ...            ...
# 948247  -100.000000                failure          2024              6
# 948247  -100.000000                failure          2024              6
# 948247  -100.000000                failure          2024              6
# 948302  -100.000000                failure          2008              2
# 948302  -100.000000                failure          2008              2
#
#        released_day
# 3                15
# 3                15
# 3                15
# 6                25
# 6                25
# ...             ...
# 948247           27
# 948247           27
# 948247           27
# 948302           29
# 948302           29
#
# [26447 rows x 26 columns]

# %%
# Remove duplicates based on "id" column (the unique identifier for each movie)
us_tmdb_df = us_tmdb_df.drop_duplicates(subset=['id'], keep='first')
us_tmdb_df.shape
# Out:
# (15363, 26)

# %%
# Verify whether there are still duplicate rows in a DataFrame based on the "id" column
us_tmdb_duplicate = us_tmdb_df[us_tmdb_df.duplicated(subset=['id'], keep=False)]
us_tmdb_duplicate
# Out:
# Empty DataFrame
# Columns: [id, title, vote_average, vote_count, status, release_date, revenue, runtime, budget, original_language, original_title, popularity, genres, production_companies, production_countries, spoken_languages, cast, director, writers, producers, critical_success, roi, financial_success, released_year, released_month, released_day]
# Index: []
#
# [0 rows x 26 columns]

# %%
# # Visualize and plot replationships between vote_average and revenue
# us_tmdb_df.plot.scatter(x='vote_average', y='revenue', title='Vote Average vs Revenue')

# # Visualize and plot replationships between vote_count and revenue
# us_tmdb_df.plot.scatter(x='vote_count', y='revenue', title='Vote Count vs Revenue')

# # Visualize and plot replationships between popularity and revenue
# us_tmdb_df.plot.scatter(x='popularity', y='revenue', title='Popularity vs Revenue')

# # Visualize and plot replationships between runtime and revenue
# us_tmdb_df.plot.scatter(x='runtime', y='revenue', title='Runtime vs Revenue')

# # Visualize and plot replationships between budget and revenue
# us_tmdb_df.plot.scatter(x='budget', y='revenue', title='Budget vs Revenue')

# %%
# Determine outliers
# Separate cast and crew into individual columns
# Convert the release_date column to datetime and extract features from the date
# 
# Groupby and aggregate genre & directior for further data analysis
# String Extraction for the cast column

# %%
# # Use a function to create a 'profitablity encoded' column to categorize the profitability of the movies
# def encode_profitability(profit):
#     if profit <= 0:
#         return 0
#     else:
#         return 1
    
# us_tmdb_df['profitability_encoded'] = us_tmdb_df['profitability'].apply(encode_profitability)

# %% [markdown]
# ## Splitting Data

# %%
# Creat a list of features to include in the model:
features = ['vote_average','vote_count','budget']

X = us_tmdb_df[features]
X.head()

# %%
# Set the target variable y
y = us_tmdb_df['revenue']

# %%
# Split the data into training and testing sets again
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# ## Modeling

# %%
# Create the model
lr_model = LinearRegression()

# Fit the model to the training data. 
lr_model.fit(X_train, y_train)

# %%
# Calculate the mean_squared_error and the r-squared value for the testing data
# Use lr_model to predict the y values
predictions = lr_model.predict(X_test)

# Score the predictions with mse and r2
mse = mean_squared_error(y_test, predictions)
r2 = r2_score(y_test, predictions)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")

# %%
# Provided code to create the adjusted r-squared function
def r2_adj(x, y, model):
    r2 = model.score(x,y)
    n_cols = x.shape[1]
    return 1 - (1 - r2) * (len(y) - 1) / (len(y) - n_cols - 1)

# %%
# Calculate the adjusted r-squared value of the model
adj_score = r2_adj(X_test, y_test, lr_model)

print(f"Adjusted R2: {adj_score}")

# %%
# Use the statsmodels package to create and fit a linear regression
lr_sm = sm.OLS(y_train, X_train).fit()

# Show the p-values of all columns sorted in ascending order
lr_sm.pvalues.sort_values()

# %%
# # Create a function to calculate VIF

# def calc_vif(X):
#     vif = pd.DataFrame()
#     vif["variables"] = X.columns
#     vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
#     return(vif)

# # Calculate vif for the dataframe
# calc_vif(X_train).sort_values(by='VIF',ascending=False)

# %% [markdown]
# ## Standardization

# %% [markdown]
# ## Encoding

# %% [markdown]
# ## Imputation

# %% [markdown]
# ## Data Engineering

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ## Tuning & Sampling
